# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
ds=fetch_california_housing()

# %%
x_train,x_test,y_train,y_test=train_test_split(ds.data,ds.target)
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train)

# %%
print(ds.data.shape)
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (20640, 8)
# (11610, 8)
# (11610,)
# (3870, 8)
# (3870,)
# (5160, 8)
# (5160,)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_val=scaler.fit_transform(x_val)
x_test=scaler.fit_transform(x_test)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
model=Sequential ()
model.add(Dense(30, input_shape=x_train.shape[1:], activation='relu'))
model.add(Dense(18, activation='relu'))
#model.add(Dense(14, activation='leaky_relu'))
model.add(Dense(10, activation='elu'))
model.add(Dense(1))

# %%
from tensorflow.keras.metrics import mean_squared_error
model.compile(loss=mean_squared_error,optimizer='sgd')

# %%
model.fit(x_train,y_train,epochs=50, batch_size=100,validation_data=(x_val,y_val))
# Out:
# Epoch 1/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2261 - val_loss: 0.6656
# Epoch 2/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2280 - val_loss: 0.4645
# Epoch 3/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2269 - val_loss: 0.4704
# Epoch 4/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2291 - val_loss: 0.4366
# Epoch 5/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2270 - val_loss: 0.4525
# Epoch 6/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2264 - val_loss: 0.4768
# Epoch 7/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2272 - val_loss: 0.4004
# Epoch 8/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2256 - val_loss: 0.4314
# Epoch 9/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2264 - val_loss: 0.4128
# Epoch 10/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2263 - val_loss: 0.5096
# Epoch 11/50
# 117/117 [==============================] - 0s 4ms/step - loss: 0.2273 - val_loss: 0.4434
# Epoch 12/50
# 117/117 [==============================] - 0s 4ms/step - loss: 0.2257 - val_loss: 0.4373
# Epoch 13/50
# 117/117 [==============================] - 0s 4ms/step - loss: 0.2264 - val_loss: 0.4702
# Epoch 14/50
# 117/117 [==============================] - 0s 4ms/step - loss: 0.2271 - val_loss: 0.4221
# Epoch 15/50
# 117/117 [==============================] - 1s 4ms/step - loss: 0.2258 - val_loss: 0.4201
# Epoch 16/50
# 117/117 [==============================] - 1s 4ms/step - loss: 0.2254 - val_loss: 0.4513
# Epoch 17/50
# 117/117 [==============================] - 0s 4ms/step - loss: 0.2270 - val_loss: 0.4146
# Epoch 18/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2263 - val_loss: 0.4657
# Epoch 19/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2259 - val_loss: 0.4876
# Epoch 20/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2268 - val_loss: 0.4814
# Epoch 21/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2272 - val_loss: 0.5434
# Epoch 22/50
# 117/117 [==============================] - 0s 2ms/step - loss: 0.2269 - val_loss: 0.4548
# Epoch 23/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2268 - val_loss: 0.4515
# Epoch 24/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2260 - val_loss: 0.3965
# Epoch 25/50
# 117/117 [==============================] - 0s 2ms/step - loss: 0.2266 - val_loss: 0.5100
# Epoch 26/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2271 - val_loss: 0.4569
# Epoch 27/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2261 - val_loss: 0.4311
# Epoch 28/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2258 - val_loss: 0.4283
# Epoch 29/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2260 - val_loss: 0.4119
# Epoch 30/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2266 - val_loss: 0.4223
# Epoch 31/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2260 - val_loss: 0.4700
# Epoch 32/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2256 - val_loss: 0.4702
# Epoch 33/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2262 - val_loss: 0.4363
# Epoch 34/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2247 - val_loss: 0.4698
# Epoch 35/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2263 - val_loss: 0.4295
# Epoch 36/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2257 - val_loss: 0.5178
# Epoch 37/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2271 - val_loss: 0.4337
# Epoch 38/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2253 - val_loss: 0.5280
# Epoch 39/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2262 - val_loss: 0.4302
# Epoch 40/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2267 - val_loss: 0.4381
# Epoch 41/50
# 117/117 [==============================] - 0s 2ms/step - loss: 0.2255 - val_loss: 0.4198
# Epoch 42/50
# 117/117 [==============================] - 0s 2ms/step - loss: 0.2261 - val_loss: 0.4156
# Epoch 43/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2254 - val_loss: 0.4421
# Epoch 44/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2248 - val_loss: 0.4635
# Epoch 45/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2249 - val_loss: 0.4662
# Epoch 46/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2257 - val_loss: 0.4480
# Epoch 47/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2255 - val_loss: 0.4792
# Epoch 48/50
# 117/117 [==============================] - 0s 3ms/step - loss: 0.2256 - val_loss: 0.4392
# Epoch 49/50
# 117/117 [==============================] - 0s 4ms/step - loss: 0.2247 - val_loss: 0.4135
# Epoch 50/50
# 117/117 [==============================] - 1s 4ms/step - loss: 0.2252 - val_loss: 0.5546

# %%
accuracy = model.evaluate(x_test, y_test, verbose = 0) 

#print('Test loss:', loss_score) 
print('Test accuracy:', accuracy*100)
# Out:
# Test accuracy: 56.93296194076538
